# %%
pip install mysql-connector-python SQLAlchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import mysql.connector
from sqlalchemy import create_engine

# %%
# !pip install xlrd==2.0.1

# %%
df = pd.read_excel("C:/Users/ANKIT/Documents/BEPEC/INX future project/INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xlsx")
df.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %%
df.isnull().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# ...

# %%
df.shape
# Out:
# (1200, 28)

# %%
df.isna().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# ...

# %%
df["Attrition"].apply(lambda x: 1 if str(x).lower() == 'yes' else 0)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1195    0
# 1196    0
# 1197    0
# 1198    0
# 1199    1
# Name: Attrition, Length: 1200, dtype: int64

# %%
df['Attrition'].value_counts()
# Out:
# No     1022
# Yes     178
# Name: Attrition, dtype: int64

# %%
df["Attrition"] = df["Attrition"].astype(str).str.strip().str.lower()
print(df["Attrition"].unique())
# Out:
# ['no' 'yes']

# %%
#df["Attrition"]= df["Attrition"].apply(lambda x: 1 if str(x) == 'yes' else 0)
df['Attrition'].value_counts()
# Out:
# no     1022
# yes     178
# Name: Attrition, dtype: int64

# %%
df['Attrition'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df.head(5)
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %%
df['ExternalExperience'] = df['TotalWorkExperienceInYears'] - df['ExperienceYearsAtThisCompany']
df.columns
# Out:
# Index(['EmpNumber', 'Age', 'Gender', 'EducationBackground', 'MaritalStatus',
#        'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency',
#        'DistanceFromHome', 'EmpEducationLevel', 'EmpEnvironmentSatisfaction',
#        'EmpHourlyRate', 'EmpJobInvolvement', 'EmpJobLevel',
#        'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime',
#        'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction',
#        'TotalWorkExperienceInYears', 'TrainingTimesLastYear',
#        'EmpWorkLifeBalance', 'ExperienceYearsAtThisCompany',
#        'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition', 'PerformanceRating',
#        'ExternalExperience'],
#       dtype='object')

# %%
df.head(5)
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  TotalWorkExperienceInYears  TrainingTimesLastYear  \
# ...

# %%
df.std(axis=None)
# Out:
# C:\Users\ANKIT\AppData\Local\Temp\ipykernel_8076\1193620216.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std(axis=None)
# Age                              9.087289
# DistanceFromHome                 8.176636
# EmpEducationLevel                1.044120
# EmpEnvironmentSatisfaction       1.090599
# EmpHourlyRate                   20.211302
# EmpJobInvolvement                0.707164
# EmpJobLevel                      1.107836
# EmpJobSatisfaction               1.100888
# NumCompaniesWorked               2.469384
# EmpLastSalaryHikePercent         3.625918
# EmpRelationshipSatisfaction      1.075642
# TotalWorkExperienceInYears       7.797228
# TrainingTimesLastYear            1.263446
# EmpWorkLifeBalance               0.699374
# ...

# %%
from sqlalchemy import create_engine

# %%
# !pip install pymysql

# %%
engine = create_engine("mysql+pymysql://root:root@localhost:3306/inx")
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/inx)

# %%
tables = pd.read_sql("SHOW TABLES;", engine)
print(tables)
# Out:
# Empty DataFrame
# Columns: [Tables_in_inx]
# Index: []

# %%
df.to_sql("employees", con=engine, if_exists="replace", index=False)
# Out:
# 1200

# %%
check = pd.read_sql("SHOW TABLES;", engine)
print(check)
# Out:
#   Tables_in_inx
# 0     employees

# %%
preview = pd.read_sql("SELECT * FROM employees LIMIT 10;", engine)
print(preview)
# Out:
#   EmpNumber  Age  Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32    Male           Marketing        Single            Sales
# 1  E1001006   47    Male           Marketing        Single            Sales
# 2  E1001007   40    Male       Life Sciences       Married            Sales
# 3  E1001009   41    Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60    Male           Marketing        Single            Sales
# 5  E1001011   27    Male       Life Sciences      Divorced      Development
# 6  E1001016   50    Male           Marketing       Married            Sales
# 7  E1001019   28  Female       Life Sciences        Single      Development
# 8  E1001020   36  Female       Life Sciences       Married      Development
# 9  E1001021   38  Female       Life Sciences        Single      Development
#
#              EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# ...
